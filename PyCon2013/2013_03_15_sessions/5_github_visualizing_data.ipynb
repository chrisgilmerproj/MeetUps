# %% [markdown]
# ## Github Visualizing Data

# %% [raw]
# Dana Bauer @geography76 - Data Information
# Idan Gazit @idangazit - Information to Meaning

# %% [raw]
# Mapping meaning onto data
#
# "Visualizing Data" - Ben Fry
#
# Part 1: Aquire - parse - filter - mine -
# Part 2: represent - refine - interact

# %% [raw]
# Part 1: Dana Bauer
#
# Work with people who have mix of skills and the process should not be linear
#
# Step 1 - Aquiring the data
#
# Github has
# 3.4 million users
# 5.7 million repos
#
# Choose a Meaningful Subset (filtering)
#
# Github.com/languages - pick top 10
#
# Strategies:
# - API Whitelist
# - Repo Cloning
#
# Cloud - Use Amazon Web, EC2
# - Flexibility
# - Storage (100GB for 2000 repos)
# - Stability for long running operations
# - Can upgrade size quickly
# - Speed
#
# Tooling:
# - 100gb EBS volume
# - user-data scripts
# - bare metal -> ready to work
# - iPython
# - fabric
#
#
# Step 2 - Parsing and Filtering
# - Made snapshot of image
# - Attach data to EBS volume
# - expose iPython notebook, but connection is a problem
#
# Ended up using tmux for long running processes
#
# Inception: shells inside your shells
#
# Always reattach to tmux session
#
# Double your REPL, Double your fun
# attach tmux session for pair programming
#
# Storing results
# - MongoDB
# - Hosted cheap, data crunching on a budget
# - No schema, no joins, no problem
#
# Network
# - git != github
# - authors != github users
#
# Celery
# - an asynchronous task queue with nifty features
# - Heroku first dyno is free, can put up celery there
# - Task broker, result store
# - Redis for broker, result store
# - heroku add ons
#
# Step 3 - Mining for understanding
# - Lots of messy data, had to muck around
# - Dynamic data, changes constantly
# - Idempotency (do repeat yourself)
# - Help others repeat your data

# %% [raw]
# Part 2: Idan Gazit
#
# umbrella.io
#
# Design is constraints
# Chicken and Egg problem
#
# Step 5 - Choosing a visual representation
# In the end, creating a story
#
# Meaning requires context
# - Choosing a medium (the web)
# - Choosing an audience (for geeks)
# - "One size fits nobody"
#
# Assume knows github, familiar with code and dev, curious about community
#
# Know the audience
#
# Eye candy trap - Beautiful noise is still just noise
#
# Logo for the modern computer
# see: processing.js (not great for web)
#
# D3.js is the thing (Data driven documents)
# A data visualization toolkit for the web
#
# mapping data onto meaningful visuals (the DOM)
#
# Scales:
# - linear
# - logrithmic
# - quantile
# - ordinal
# - time
#
# Interpolaton:
# - dimension
# - position
# - color
# - orientation
#
# Good visualization encodes a lot of dimensions
# - Its a delicate balance
#
# SVG - not just an image (xml)
# JSON & CSV
#
# Intermediate representations
#
# JSON
# - Easy to serialize
# - Structured
# - Preserves data types
# - Bloated for tabular data
#
# CSV
# - mostly easy to serialize to
# - Structured
# - Comes out on other end as a dict
# - Everything comes back as text
#
# Hybridize! (tabular data in csv, meta data in json)
# - name
# - user
# - rank
# - watchers
# - commits
# - size
# - earliest commit
#
# Precalculate where possible
#
# Caching, Caching, Caching
# - Static files in RESTful format
#
# What do we want to show? - no idea
#
# Frustration - "Plan to throw some away"
#
# dataviz requires a lot of effort and you will have to throw some away
#
# What to view in Dataset:
# - People
# - Languages
# - Repositories
#
# Live Demo Time!
