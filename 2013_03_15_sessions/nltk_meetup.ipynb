# %% [raw]
# adamich
#
# network
#
# y.y. ahn
#
# courser network analysis class
#
# markov
#
# hidden markov model
#
# viterbi - filtering method lattice method smallest weight
# dynamic programming
#
# gate.ac.uk
#
# treebanks
# graph search
#
# http://text-processing.com/
# - check out demo for tokenizer
#
# collins coursera
#
# networkx
#
# nltk chunker
#
# pretrained brill tagger
# pposttl - build c code first, faster than brill tagger
# https://github.com/kylebgorman/pposttl
#
# gposttl -
# http://gposttl.sourceforge.net/
#
# brill tagger really good once trained, but takes work and is slow in python
# - try the pposttl
#
# use an nltk chunker to get out noun phrases
#
# penn phonetics lab, toolkit
#
#
# nltk discsussing group
# open nlp project (java)
#
# searching
#
# inverted-index language model
# transpose a sparse matrix, offsets (bigrams, trigrams)
#
# sunlight laws - Capital Words
#
# Use Simplified Tags (not all the brown tags, its like 5:1)
#
# Reverse taggers (Regex -> Bigram -> Unigram)
#
# Steps for new corpus:
# 1. Find big text
# 2. Train using Brown Corpus
# 3. Correct corpus by hand
# 4. Retrain tagger using new corpus
# 5. $Profit
#
# Help from NLTK Cookbook guy:
# japerk@gmail.com
# streamhacker.com
